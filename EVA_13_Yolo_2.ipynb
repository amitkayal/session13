# %% [markdown]
# # Implementing Yolo-V3 over toothles images

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import numpy as np
import cv2 
import os
import time
import glob
import torch
import os

from IPython.display import Image, clear_output

# %%
os.listdir()
# Out:
# ['.config', 'drive', 'sample_data']

# %%
os.chdir('YoloV3')  
# !ls
# Out:
#  annotation_tool   README.md	       train_batch0.png
#  cfg		  'results (1).json'   train.py
#  data		   results.json       'ubdivisions=1'
#  detect.py	   results.png	       utils
#  models.py	   results.txt	      'vim (1).exe.stackdump'
#  out_out	   runs		       vim.exe.stackdump
#  output		   test_batch0.png     weights
#  pred_detect.py    test.py
#  __pycache__	   ting

# %%
#!python train.py --data data/custom/custom.data --batch 10 --cache --epochs 25 --nosave

# %%
# !python train.py --data data/customdata/custom.data --batch 10 --cache --cfg cfg/yolov3-custom.cfg --epochs 10 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=10, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=10, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# 2020-07-04 16:13:19.746410: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# Caching labels (225 found, 0 missing, 2 empty, 0 duplicate, for 227 images): 100% 227/227 [00:00<00:00, 994.59it/s]
# Caching images (0.1GB): 100% 227/227 [02:09<00:00,  1.75it/s]
# ...

# %%
# !python pred_detect.py --conf-thres 0.05 --output out_out
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.05, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='out_out', save_txt=False, source='data/customdata/to_pred', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# image 1/479 data/customdata/to_pred/frame0.jpg: 320x512 Done. (0.032s)
# image 2/479 data/customdata/to_pred/frame1.jpg: 320x512 Done. (0.031s)
# image 3/479 data/customdata/to_pred/frame10.jpg: 320x512 Done. (0.031s)
# image 4/479 data/customdata/to_pred/frame100.jpg: 320x512 2 Mjolnirs, Done. (0.031s)
# image 5/479 data/customdata/to_pred/frame101.jpg: 320x512 Done. (0.031s)
# image 6/479 data/customdata/to_pred/frame102.jpg: 320x512 Done. (0.031s)
# ...
